# %% [markdown]
# # Data analysis with Pandas and Seaborn
#
# EN: This database uses the churn number of a telecommunications company's customers. Churn is a metric that indicates the rate of customer evasion. In this case, churn is defined as the loss of customers to competitors or due to a lack of interest in continuing with the service. The objective of this study is to analyze the data and identify the main factors that lead a customer to cancel the service.
#
# - `customer_id`: customer's unique identifier
# - `gender`: customer's gender
# - `elderly`: indicates whether the customer is elderly (over 65) or not
# - `has_partner`: indicates whether the customer has a partner or not
# - `has_dependents`: indicates whether the customer has dependents or not
# - `company_months`: number of months the customer has been with the company
# - `telephone_service`: indicates whether the customer has telephone service or not
# - `multiple_lines`: indicates whether the customer has multiple lines or not
# - `internet_service`: indicates whether the customer has internet service (DSL or fiber optic) or not
# - `security_service`: indicates whether the client has an online security service or not
# - `backup_service`: indicates whether the client has an online backup service or not
# - `equipment_protection_service`: indicates whether the client has a connection equipment protection service or not
# - `technical_support_service`: indicates whether the client has priority technical support service or not
# - `streaming_tv`: indicates whether the client has a TV streaming service or not
# - `streaming_films`: indicates whether the customer has a movie streaming service or not
# - `contract`: type of customer contract (monthly, annual or two years)
# - `digital_invoice`: indicates whether the customer receives the invoice by e-mail or not
# - `payment_form`: customer's payment method (check, bank slip, bank transfer or credit card)
# - `monthly_value`: monthly value of the contracted service
# - `total_spend`: total amount spent by the customer
# - `churn`: indicates whether the customer canceled the service in the previous month or not
#
# PT: Esta base de dados utiliza o número churn de clientes de uma empresa de telecomunicações. O churn é uma métrica que indica a taxa de evasão de clientes. Neste caso, o churn é definido como a perda de clientes para a concorrência ou por desinteresse em continuar com o serviço. O objetivo deste estudo é analisar os dados e identificar os principais fatores que levam um cliente a cancelar o serviço.
#
# Temos o seguinte dicionário de dados:
#
# - `id_cliente`: identificador único do cliente
# - `genero`: gênero do cliente
# - `idoso`: indica se o cliente é idoso (mais de 65 anos) ou não
# - `tem_parceiro`: indica se o cliente tem parceiro ou não
# - `tem_dependentes`: indica se o cliente tem dependentes ou não
# - `meses_na_empresa`: quantidade de meses que o cliente permaneceu na empresa
# - `servico_telefone`: indica se o cliente tem serviço de telefone ou não
# - `multiplas_linhas`: indica se o cliente tem múltiplas linhas ou não
# - `servico_internet`: indica se o cliente tem serviço de internet (DSL ou fibra óptica) ou não
# - `servico_seguranca`: indica se o cliente tem serviço de segurança online ou não
# - `servico_backup`: indica se o cliente tem serviço de backup online ou não
# - `servico_protecao_equipamento`: indica se o cliente tem serviço de proteção do equipamento de conexão ou não
# - `servico_suporte_tecnico`: indica se o cliente tem serviço de suporte técnico prioritário ou não
# - `streaming_tv`: indica se o cliente tem serviço de streaming de TV ou não
# - `streaming_filmes`: indica se o cliente tem serviço de streaming de filmes ou não
# - `contrato`: tipo de contrato do cliente (mensal, anual ou dois anos)
# - `fatura_digital`: indica se o cliente recebe a fatura por e-mail ou não
# - `forma_pagamento`: forma de pagamento do cliente (cheque, boleto, transferência bancária ou cartão de crédito)
# - `valor_mensal`: valor mensal do serviço contratado
# - `total_gasto`: valor total gasto pelo cliente
# - `churn`: indica se o cliente cancelou o serviço no mês anterior ou não

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

ARQUIVO_DADOS = 'churn_clientes.csv'

df_churn = pd.read_csv(ARQUIVO_DADOS)
df_churn.head()
# Out:
#    id_cliente     genero idoso tem_parceiro tem_dependentes  meses_na_empresa  \
# 0  7590-VHVEG   Feminino   Não          Sim             Não                 1
# 1  5575-GNVDE  Masculino   Não          Não             Não                34
# 2  3668-QPYBK  Masculino   Não          Não             Não                 2
# 3  7795-CFOCW  Masculino   Não          Não             Não                45
# 4  9237-HQITU   Feminino   Não          Não             Não                 2
#
#   servico_telefone multiplas_linhas servico_internet servico_seguranca  ...  \
# 0              Não              Não              DSL               Não  ...
# 1              Sim              Não              DSL               Sim  ...
# 2              Sim              Não              DSL               Sim  ...
# 3              Não              Não              DSL               Sim  ...
# 4              Sim              Não     Fibra optica               Não  ...
#
# ...

# %%
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id_cliente                    7043 non-null   object
#  1   genero                        7043 non-null   object
#  2   idoso                         7043 non-null   object
#  3   tem_parceiro                  7043 non-null   object
#  4   tem_dependentes               7043 non-null   object
#  5   meses_na_empresa              7043 non-null   int64
#  6   servico_telefone              7043 non-null   object
#  7   multiplas_linhas              7043 non-null   object
#  8   servico_internet              7043 non-null   object
#  9   servico_seguranca             7043 non-null   object
#  10  servico_backup                7043 non-null   object
#  11  servico_protecao_equipamento  7043 non-null   object
# ...

# %%
df_churn.describe()
# Out:
#        meses_na_empresa  valor_mensal  total_gasto
# count       7043.000000   7043.000000  7043.000000
# mean          32.371149     64.761692  2281.916928
# std           24.559481     30.090047  2265.270398
# min            0.000000     18.250000    18.800000
# 25%            9.000000     35.500000   402.225000
# 50%           29.000000     70.350000  1397.475000
# 75%           55.000000     89.850000  3786.600000
# max           72.000000    118.750000  8684.800000

# %%
df_churn.describe(exclude='number')
# Out:
#         id_cliente     genero idoso tem_parceiro tem_dependentes  \
# count         7043       7043  7043         7043            7043
# unique        7043          2     2            2               2
# top     7590-VHVEG  Masculino   Não          Não             Não
# freq             1       3555  5901         3641            4933
#
#        servico_telefone multiplas_linhas servico_internet servico_seguranca  \
# count              7043             7043             7043              7043
# unique                2                2                3                 2
# top                 Sim              Não     Fibra optica               Não
# freq               6361             4072             3096              5024
#
#        servico_backup servico_protecao_equipamento servico_suporte_tecnico  \
# count            7043                         7043                    7043
# unique              2                            2                       2
# ...

# %% [markdown]
# EN: Now we know that the majority of customers:
#
# - are male
# - are younger than 65
# - have no partner or dependents
# - have a telephone service, with a single line
# - have fiber optic internet service
# - no online services (security, backup, device protection)
# - no technical support
# - no streaming services
# - monthly contracts
# - have digital billing and pay by boleto
#
# The target variable *churn* has "No" as the most frequent value, occurring 5174 times.
#
# PT: Agora sabemos que a maioria dos clientes:
#
# - é do sexo masculino
# - é mais jovem que 65 anos
# - não tem parceiro e nem dependentes
# - tem serviço de telefone, com uma única linha
# - tem serviço de internet por fibra óptica
# - não tem serviços online (segurança, backup, proteção de dispositivo)
# - não tem suporte técnico
# - não tem serviços de streaming
# - tem contratos mensais
# - tem faturamento digital e pagam com boleto
#
# A variável alvo *churn* tem "Não" como o valor mais frequente, ocorrendo 5174 vezes.

# %%
df_churn['churn'].value_counts()
# Out:
# Não    5174
# Sim    1869
# Name: churn, dtype: int64

# %%
df_churn['churn'].value_counts(normalize=True) * 100
# Out:
# Não    73.463013
# Sim    26.536987
# Name: churn, dtype: float64

# %%
# drop da coluna id_cliente
df_churn = df_churn.drop(columns='id_cliente', axis=1)
df_churn.head()
# Out:
#       genero idoso tem_parceiro tem_dependentes  meses_na_empresa  \
# 0   Feminino   Não          Sim             Não                 1
# 1  Masculino   Não          Não             Não                34
# 2  Masculino   Não          Não             Não                 2
# 3  Masculino   Não          Não             Não                45
# 4   Feminino   Não          Não             Não                 2
#
#   servico_telefone multiplas_linhas servico_internet servico_seguranca  \
# 0              Não              Não              DSL               Não
# 1              Sim              Não              DSL               Sim
# 2              Sim              Não              DSL               Sim
# 3              Não              Não              DSL               Sim
# 4              Sim              Não     Fibra optica               Não
#
#   servico_backup servico_protecao_equipamento servico_suporte_tecnico  \
# ...

# %%
colunas_numericas = df_churn.select_dtypes(include='number').columns
colunas_categoricas = df_churn.select_dtypes(exclude='number').columns

print(colunas_numericas)
print(colunas_categoricas)
# Out:
# Index(['meses_na_empresa', 'valor_mensal', 'total_gasto'], dtype='object')
# Index(['genero', 'idoso', 'tem_parceiro', 'tem_dependentes',
#        'servico_telefone', 'multiplas_linhas', 'servico_internet',
#        'servico_seguranca', 'servico_backup', 'servico_protecao_equipamento',
#        'servico_suporte_tecnico', 'streaming_tv', 'streaming_filmes',
#        'contrato', 'fatura_digital', 'forma_pagamento', 'churn'],
#       dtype='object')

# %%
colunas_categoricas = colunas_categoricas.drop('churn')
print(colunas_categoricas)
# Out:
# Index(['genero', 'idoso', 'tem_parceiro', 'tem_dependentes',
#        'servico_telefone', 'multiplas_linhas', 'servico_internet',
#        'servico_seguranca', 'servico_backup', 'servico_protecao_equipamento',
#        'servico_suporte_tecnico', 'streaming_tv', 'streaming_filmes',
#        'contrato', 'fatura_digital', 'forma_pagamento'],
#       dtype='object')

# %% [markdown]
# ## Histogram

# %%
sns.set_theme(style='dark', palette='bright', context='notebook')

sns.histplot(x='meses_na_empresa', data=df_churn, hue='contrato');

# %% [markdown]
# ## KDE

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(14, 6), tight_layout=True)

for i, coluna in enumerate(colunas_numericas):
    sns.kdeplot(x=coluna, hue='contrato', data=df_churn, fill=True, ax=axs[i])

plt.show()

# %% [raw]
# In addition, I identified that the majority of customers with a monthly contract canceled their service in the previous month by using `hue` to separate the data according to the `churn` variable. In contrast, the majority of customers with an annual or two-year contract did not cancel their service in the previous month.

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(14, 6), tight_layout=True)

for i, coluna in enumerate(colunas_numericas):
    sns.histplot(x=coluna, hue='churn', data=df_churn, multiple='stack', ax=axs[i])

plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(14, 6), tight_layout=True)

for i, coluna in enumerate(colunas_numericas):
    sns.kdeplot(x=coluna, hue='churn', data=df_churn, fill=True, ax=axs[i])

plt.show()

# %% [markdown]
# ## FacetGrid

# %%
g = sns.FacetGrid(df_churn, col='contrato', hue='churn')
g.map_dataframe(sns.histplot, x='meses_na_empresa')
g.add_legend()
plt.show()

# %%
g = sns.FacetGrid(df_churn, row='churn', col='contrato')
g.map_dataframe(sns.histplot, x='meses_na_empresa')
plt.show()

# %%
g = sns.FacetGrid(df_churn, col='contrato', hue='churn')
g.map_dataframe(sns.scatterplot, x='valor_mensal', y='total_gasto')
g.add_legend()
plt.show()

# %% [markdown]
# ## Pairplot

# %%
sns.pairplot(data=df_churn, hue='churn')
plt.show()

# %%
sns.pairplot(data=df_churn, hue='churn', diag_kind='hist')
plt.show()

# %% [markdown]
# ## Boxplot

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(16, 4), tight_layout=True, sharey=True)

for i, coluna in enumerate(colunas_numericas):
    sns.boxplot(x=coluna, y='churn', data=df_churn, ax=axes[i])

plt.show()

# %% [raw]
# The boxplots show that the churn rate is higher among customers with less time with the company and higher monthly fees. In detail:
#
# - the median number of months for customers who left is around 10 months, while for those who stayed it is around 40 months
# - the median monthly fee for customers who canceled is around 80, while for those who didn't cancel it's around 65
# - as the majority of customers who canceled spent less time with the company, they have lower total charges compared to those who remained
#   - There are many outliers in the boxplot of total charges for customers who canceled. It's not clear why, but it could be mischarging or expensive services that have driven customers away from the company.
